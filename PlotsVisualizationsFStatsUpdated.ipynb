# %% [markdown]
# <a href="https://colab.research.google.com/github/shanksghub/FootballStats/blob/master/PlotsVisualizationsFStatsUpdated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This project is to evaluate player performance and comparision using different metrics.

# %% [markdown]
# Lets first import relevant libraries and the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


url = 'https://raw.githubusercontent.com/shanksghub/FootballStats/master/FootballStats.csv'
df = pd.read_csv(url)

# %% [markdown]
# Lmplot to compare Goals with respect to assists.

# %%
sns.lmplot(x='goals', y='passes', data=df,fit_reg=True)

# %% [markdown]
# Lmplot to compare red cards with respect to yellow cards.

# %%
sns.lmplot(x='red cards', y='yellow cards', data=df,fit_reg=True)

# %% [markdown]
# Lmplot to compare Goals with respect to appearances.

# %%
sns.lmplot(x='goals', y='appearances', data=df,fit_reg=True)

# %% [markdown]
# Lmplot to compare Goals with respect to passes.

# %%
sns.lmplot(x='goals', y='passes', data=df,fit_reg=True)

# %% [markdown]
# Heatmap to correlate stats of Forwards

# %%
fFrame = df.loc[df['position'] == 'Forward']

corr = fFrame.corr()
 
# Heatmap
sns.heatmap(corr)

# %% [markdown]
# Heatmap to correlate stats of Midfielders.

# %%
fFrame = df.loc[df['position'] == 'Midfielder']

corr = fFrame.corr()
 
sns.heatmap(corr)

# %% [markdown]
# Heatmap to correlate stats of Defenders.

# %%
fFrame = df.loc[df['position'] == 'Defender']
corr = fFrame.corr()
 
sns.heatmap(corr)

# %% [markdown]
# Barplot with certain features.

# %%
dff = df.drop(['appearances','goals conceded','hit woordwork','headed clearances','clearances','saves','punches','yellow cards','red cards','clean sheets'], axis=1)
sns.boxplot(data=dff)

# %% [markdown]
# ViolinPlot with goals and shots density comparision.

# %% [markdown]
# violinPlot with goals density.

# %%
sns.set_style('whitegrid')
 
sns.violinplot(x='goals', y='shots', data=df)

# %% [markdown]
# Barplot with certain features.

# %%
dff = df.drop(['appearances','hit woordwork','crosses','assists','name','blocks','fouls','goals conceded','headed clearances','clearances','saves','punches','yellow cards','red cards','offsides','clean sheets'], axis=1)
 
sns.boxplot(data=dff)

# %% [markdown]
# Barplot with Goalkeepers statistics.

# %%
dffd = df.drop(['appearances','hit woordwork','crosses','assists','name','blocks','fouls','yellow cards','red cards','offsides','goals','shots','tackles','passes'], axis=1)
 
sns.boxplot(data=dffd)

# %% [markdown]
# Barplot with statistics including bookings.

# %%
dff = df.drop(['appearances','hit woordwork','crosses','assists','name','blocks','goals conceded','headed clearances','clearances','saves','punches','clean sheets'], axis=1)
 
sns.boxplot(data=dff)

# %% [markdown]
# Heatmap with Goalkeeper statistics correlation.

# %%
fFrame = df.loc[df['position'] == 'Goalkeeper']

corr = fFrame.corr()
 
sns.heatmap(corr)

# %% [markdown]
# Heatmap with  statistics correlation.

# %%
corr = df.corr()
 
# Heatmap
sns.heatmap(corr)

# %% [markdown]
# Distplot of goals.

# %%
sns.distplot(df.goals)

# %% [markdown]
# Distplot of Shots.

# %%
sns.distplot(df.shots)

# %% [markdown]
# Countplot of Goals.

# %%
sns.countplot(x='goals', data=df)

# %% [markdown]
# Countplot of Shots

# %%
sns.countplot(x='shots', data=df)

# %% [markdown]
# Countplot of blocks.

# %%
sns.countplot(x='blocks', data=df)

# %%
sns.countplot(x='crosses', data=df)

# %% [markdown]
# Countplot of crosses.

# %%
sns.countplot(x='crosses', data=df)

# %% [markdown]
# Distplot of goals by Forwards

# %%
fFrame = df.loc[df['position'] == 'Forward']

sns.distplot(fFrame.goals)

# %% [markdown]
# KDEplot of Assists and Shots.

# %%
sns.kdeplot(df.assists, df.shots)

# %% [markdown]
# KDE plot of goals and shots.

# %%
sns.kdeplot(df.goals, df.shots)

# %% [markdown]
# KDEPlot of assists and shots of Forwards.

# %%
fFrame = df.loc[df['position'] == 'Forward']

sns.kdeplot(fFrame.assists, fFrame.shots)

# %% [markdown]
# KDEPlot of goals and shots of Forwards.

# %%
fFrame = df.loc[df['position'] == 'Forward']

sns.kdeplot(fFrame.goals, fFrame.shots)

# %% [markdown]
# KDEPlot of goals and shots of Forwards.

# %%
fFrame = df.loc[df['position'] == 'Forward']

sns.kdeplot(fFrame.goals, fFrame.shots)

# %% [markdown]
# KDEPlot of passes and shots of Forwards.

# %%
fFrame = df.loc[df['position'] == 'Forward']

sns.kdeplot(fFrame.goals, fFrame.passes)

# %% [markdown]
# Barplot of Yellow cards and Red Cards.

# %%
sns.barplot(x='yellow cards',y='red cards',data=df)

# %% [markdown]
# Barplot of Tackles and Yellow Cards.

# %%
sns.barplot(x='yellow cards',y='tackles',data=df)f

# %% [markdown]
# Barplot of tackles and red cards.

# %%
sns.barplot(x='tackles',y='red cards',data=df)

# %% [markdown]
# Barplot of red cards and tackles of Forwards.

# %%
fFrame = df.loc[df['position'] == 'Forward']

sns.barplot(x='red cards',y='tackles',data=fFrame)

# %% [markdown]
# Stripplot of assists and goals .

# %%
sns.stripplot(x="assists", y='goals', data=df)

# %% [markdown]
# Stripplot of position and goals .

# %%
sns.stripplot(x="position", y='goals', data=df)

# %% [markdown]
# Stripplot of tackles and goals.

# %%
sns.stripplot(x="tackles", y='goals', data=df)

# %% [markdown]
# Stripplot of clearances and blocks.

# %%
sns.stripplot(x="clearances", y='blocks', data=df)

# %% [markdown]
# Pairplot

# %%
sns.pairplot(fFrame,palette='rainbow')
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# Pairplot

# %%
sns.pairplot(df,palette='rainbow')
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# Swarmplot of Position and Goals.

# %%
sns.swarmplot(x="position", y="goals", data=df)

# %% [markdown]
# Lmplot of shots and goals of all positions.

# %%
sns.lmplot(x='shots',y='goals',data=df,hue='position')

# %% [markdown]
# Lmplot of passes and goals of all positions.

# %%
sns.lmplot(x='goals',y='passes',data=df,hue='position')

# %% [markdown]
# Lmplot of assists and goals of all positions.

# %%
sns.lmplot(x='assists',y='passes',data=df,hue='position')

# %% [markdown]
# Lmplot of fouls and goals of all positions.

# %%
sns.lmplot(x='goals',y='fouls',data=df,hue='position')

# %% [markdown]
# Lmplot of blocks and passes of all positions.

# %%
sns.lmplot(x='blocks',y='passes',data=df,hue='position')

# %% [markdown]
# Lmplot of red cards and yellow cards of all positions.

# %%
sns.lmplot(x='red cards',y='yellow cards',data=df,hue='position')

# %% [markdown]
# ViolinPlot of goals and position.

# %%
sns.violinplot(x="goals", y="position", data=df,palette='rainbow')

# %% [markdown]
# Combination of Goals and position swarmplot and Shots and position violinplot.

# %%
sns.swarmplot(x="goals", y="position", data=df,color='red',size=3)
sns.violinplot(x="shots", y="position", data=df,palette='rainbow')

# %% [markdown]
# Swarmplot of goals and positions.

# %%
sns.swarmplot(x="goals", y="position", data=df,color='red',size=3)

# %% [markdown]
# violin plot of Goals and Positions.

# %%
sns.violinplot(x="goals", y="position", data=df,palette='rainbow')

# %%
fFrame = df.loc[df['position'] == 'Defender']
sns.distplot(df.goals)

fFrame = df.loc[df['position'] == 'Midfielder']
sns.distplot(fFrame.goals)


fFrame = df.loc[df['position'] == 'Forward']
sns.distplot(fFrame.goals)

# %%
fFrame = df.loc[df['position'] == 'Midfielder']
sns.distplot(fFrame.goals)

# %% [markdown]
# Displot of Shots of Midfielder and Forward.

# %%
fFrame = df.loc[df['position'] == 'Midfielder']
sns.distplot(fFrame.shots)


fFrame = df.loc[df['position'] == 'Forward']
sns.distplot(fFrame.shots)

# %% [markdown]
# Distplot of goals of Forwards.

# %%
fFrame = df.loc[df['position'] == 'Forward']
sns.distplot(fFrame.goals)

# %% [markdown]
# Distplot of assists of Midfielder.

# %%
fFrame = df.loc[df['position'] == 'Midfielder']
sns.distplot(fFrame.assists)

# %% [markdown]
# Distplot of shots of Defenders.

# %%
fFrame = df.loc[df['position'] == 'Defender']
sns.distplot(fFrame.shots)

# %% [markdown]
# Displots of Midfielders and Forwards and their passes.

# %%
fFrame = df.loc[df['position'] == 'Midfielder']
sns.distplot(fFrame.passes)

fFrame = df.loc[df['position'] == 'Forward']
sns.distplot(fFrame.passes)

# %% [markdown]
# Displot of clearances of Defenders.

# %%
fFrame = df.loc[df['position'] == 'Defender']
sns.distplot(fFrame.clearances)

# %% [markdown]
# Distplot of Goakeepers and saves.

# %%
fFrame = df.loc[df['position'] == 'Goalkeeper']
sns.distplot(fFrame.saves)

# %% [markdown]
# Distplot of Goalkeeper and punches.

# %%
fFrame = df.loc[df['position'] == 'Goalkeeper']
sns.distplot(fFrame.punches)

# %% [markdown]
# Distplot of Midfielders and assists.

# %%
fFrame = df.loc[df['position'] == 'Midfielder']
sns.distplot(fFrame.assists)

# %% [markdown]
# Jointplot of shots and goals.

# %%
g = sns.JointGrid(x="shots", y="goals", data=fFrame)
g = g.plot(sns.regplot, sns.distplot)

# %% [markdown]
# jJointplot of red and yellow cards of Midfielders.

# %%
fFrame = df.loc[df['position'] == 'Midfielder']

g = sns.JointGrid(x="red cards", y="yellow cards", data=fFrame)
g = g.plot(sns.regplot, sns.distplot)

# %% [markdown]
# jJointplot of red and yellow cards of Forwards.

# %%
fFrame = df.loc[df['position'] == 'Forward']

g = sns.JointGrid(x="red cards", y="yellow cards", data=fFrame)
g = g.plot(sns.regplot, sns.distplot)

# %% [markdown]
# jJointplot of goals and shots of Midfielders.

# %%
fFrame = df.loc[df['position'] == 'Midfielder']

g = sns.JointGrid(x="goals", y="shots", data=fFrame)
g = g.plot(sns.regplot, sns.distplot)
