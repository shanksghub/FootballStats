# %% [markdown]
# <a href="https://colab.research.google.com/github/shanksghub/FootballStats/blob/Project/Linear%20Regression%20Project%20Updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This project is to evaluate player performance and comparision using different metrics.Fisrt I have used some visualizations and then linear regression models.
#
# Lets first import relevant libraries and the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
url = 'https://raw.githubusercontent.com/shanksghub/FootballStats/master/FootballStats.csv'
df = pd.read_csv(url)
df = df.dropna(axis = 0, how ='any') 
df.fillna(0)
# Out:
#                          name    position  ...  fouls  offsides
# 0               Sergio Agüero     Forward  ...   18.0       0.0
# 1             Aymeric Laporte    Defender  ...    0.0       0.0
# 2               Mohamed Salah     Forward  ...   20.0      21.0
# 3   Pierre-Emerick Aubameyang     Forward  ...   11.0      17.0
# 4                  Harry Kane     Forward  ...   23.0       7.0
# 5                 Eden Hazard     Forward  ...   10.0       7.0
# 8         Alexandre Lacazette     Forward  ...   40.0      14.0
# 9         Aleksandar Mitrovic     Forward  ...   40.0      28.0
# 10            Anthony Martial     Forward  ...   13.0       5.0
# 18                    Alisson  Goalkeeper  ...    0.0       0.0
# 19                    Ederson  Goalkeeper  ...    2.0       0.0
# 20          Kepa Arrizabalaga  Goalkeeper  ...    0.0       0.0
# 27               Rui Patrício  Goalkeeper  ...    0.0       0.0
# 28            James Tarkowski    Defender  ...   21.0       4.0
# ...

# %% [markdown]
# Jointplot of Goals and Shots of Forwards.

# %%
fFrame = df.loc[df['position'] == 'Forward']

sns.jointplot(x='goals',y='shots',data=fFrame)

# %% [markdown]
# LmPlot of Forwards and many performance metrics.

# %%
fFrame = df.loc[df['position'] == 'Forward']

sns.lmplot(x='goals',y='shots',data=fFrame)

fFrame = df.loc[df['position'] == 'Forward']

sns.lmplot(x='appearances',y='goals',data=fFrame)

fFrame = df.loc[df['position'] == 'Forward']

sns.lmplot(x='assists',y='goals',data=fFrame)

fFrame = df.loc[df['position'] == 'Forward']

sns.lmplot(x='passes',y='goals',data=fFrame)

fFrame = df.loc[df['position'] == 'Forward']

sns.lmplot(x='hit woordwork',y='shots',data=fFrame)

fFrame = df.loc[df['position'] == 'Forward']

sns.lmplot(x='crosses',y='goals',data=fFrame)

# %% [markdown]
# LmPlot of Midfielders and many performance metrics.

# %%
fFrame = df.loc[df['position'] == 'Midfielder']

sns.lmplot(x='appearances',y='goals',data=fFrame)

fFrame = df.loc[df['position'] == 'Midfielder']

sns.lmplot(x='assists',y='goals',data=fFrame)

fFrame = df.loc[df['position'] == 'Midfielder']

sns.lmplot(x='passes',y='goals',data=fFrame)

fFrame = df.loc[df['position'] == 'Midfielder']

sns.lmplot(x='hit woordwork',y='shots',data=fFrame)

fFrame = df.loc[df['position'] == 'Midfielder']

sns.lmplot(x='crosses',y='goals',data=fFrame)

# %% [markdown]
# LmPlot of Defender and many performance metrics.

# %%
fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='goals',y='shots',data=fFrame)

fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='appearances',y='goals',data=fFrame)

fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='assists',y='goals',data=fFrame)

fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='passes',y='goals',data=fFrame)

fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='hit woordwork',y='shots',data=fFrame)

fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='crosses',y='goals',data=fFrame)

fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='appearances',y='blocks',data=fFrame)

fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='appearances',y='clearances',data=fFrame)

fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='appearances',y='headed clearances',data=fFrame)

fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='passes',y='blocks',data=fFrame)

fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='blocks',y='clearances',data=fFrame)

fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='clearances',y='headed clearances' ,data=fFrame)

fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='crosses',y='assists',data=fFrame)

# %%
fFrame = df.loc[df['position'] == 'Defender']

sns.lmplot(x='crosses',y='assists',data=fFrame)

# %% [markdown]
# LmPlot of Goalkeeper and many performance metrics.

# %%
fFrame = df.loc[df['position'] == 'Goalkeeper']

sns.lmplot(x='saves',y='punches',data=fFrame)

fFrame = df.loc[df['position'] == 'Goalkeeper']

sns.lmplot(x='saves',y='clean sheets',data=fFrame)

fFrame = df.loc[df['position'] == 'Goalkeeper']

sns.lmplot(x='saves',y='goals conceded',data=fFrame)

fFrame = df.loc[df['position'] == 'Goalkeeper']

sns.lmplot(x='punches',y='goals conceded',data=fFrame)
           
fFrame = df.loc[df['position'] == 'Goalkeeper']

sns.lmplot(x='punches',y='clean sheets',data=fFrame)
           
fFrame = df.loc[df['position'] == 'Goalkeeper']

sns.lmplot(x='punches',y='saves',data=fFrame)

# %% [markdown]
# Let's look at rows and columns of the dataset with player attributes.

# %%
df.head()
# Out:
#                         name  position  appearances  ...  red cards  fouls  offsides
# 0              Sergio Agüero   Forward           23  ...       15.0   18.0       0.0
# 1            Aymeric Laporte  Defender           27  ...        2.0    0.0       0.0
# 2              Mohamed Salah   Forward           26  ...        0.0   20.0      21.0
# 3  Pierre-Emerick Aubameyang   Forward           25  ...        0.0   11.0      17.0
# 4                 Harry Kane   Forward           22  ...        0.0   23.0       7.0
#
# [5 rows x 21 columns]

# %% [markdown]
# Lets view Statistical Details.

# %%
df.describe()
# Out:
#        appearances      goals    tackles  ...  red cards      fouls   offsides
# count    23.000000  23.000000  23.000000  ...  23.000000  23.000000  23.000000
# mean     24.913043   5.521739  25.173913  ...   0.869565  18.130435   4.826087
# std       1.806882   5.976238  19.389904  ...   3.123290  12.447360   7.761514
# min      20.000000   0.000000   0.000000  ...   0.000000   0.000000   0.000000
# 25%      24.000000   1.000000   8.000000  ...   0.000000  10.500000   0.000000
# 50%      25.000000   3.000000  28.000000  ...   0.000000  19.000000   1.000000
# 75%      26.000000  10.000000  38.500000  ...   0.000000  28.000000   6.000000
# max      27.000000  17.000000  69.000000  ...  15.000000  40.000000  28.000000
#
# [8 rows x 19 columns]

# %% [markdown]
# Data type of each object and Memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 0 to 45
# Data columns (total 21 columns):
# name                 23 non-null object
# position             23 non-null object
# appearances          23 non-null int64
# goals                23 non-null int64
# tackles              23 non-null int64
# passes               23 non-null float64
# assists              23 non-null int64
# shots                23 non-null int64
# hit woordwork        23 non-null int64
# crosses              23 non-null int64
# blocks               23 non-null int64
# clearances           23 non-null int64
# headed clearances    23 non-null int64
# clean sheets         23 non-null int64
# saves                23 non-null int64
# punches              23 non-null int64
# goals conceded       23 non-null int64
# yellow cards         23 non-null float64
# red cards            23 non-null float64
# fouls                23 non-null float64
# offsides             23 non-null float64
# ...

# %% [markdown]
# Jointplot of Goals and Shots.

# %%
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')

# %%
sns.jointplot(x='goals',y='shots',data=df)

# %% [markdown]
# Jointplot of goals and shots of Forwards.

# %%
fFrame = df.loc[df['position'] == 'Forward']

sns.jointplot(x='goals',y='shots',data=fFrame)

# %% [markdown]
# Jointplot of passes and goals.

# %%
sns.jointplot(x='passes',y='goals',kind='hex',data=df)

# %% [markdown]
# pairplot.

# %%
sns.pairplot(df)

# %% [markdown]
# Lmplot of goals and tackles.

# %%
sns.lmplot(x='goals',y='tackles',data=df)

# %% [markdown]
# Linear Regression Model of goals with shots,passes,tackles and crosses.

# %%
y = df['goals']

# %%
X = df[['shots', 'passes','tackles', 'crosses']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# The coefficients
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [ 0.15786458 -0.00106464 -0.02672155  0.011948  ]

# %%
predictions = lm.predict( X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 2.5244957673811554
# MSE: 9.691251682500488
# RMSE: 3.1130775259380368

# %% [markdown]
# Distplot of Goals.

# %%
sns.distplot((y_test-predictions),bins=50);

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#          Coeffecient
# shots       0.157865
# passes     -0.001065
# tackles    -0.026722
# crosses     0.011948

# %% [markdown]
# Linear Regression of Clean Sheets and punches and saves.

# %%
y = df['clean sheets']
X = df[['punches','saves']]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
print('Coefficients: \n', lm.coef_)
predictions = lm.predict( X_test)
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Coefficients:
#  [1.01770144 0.02213019]
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
sns.distplot((y_test-predictions),bins=50);
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
# MAE: 1.9332757420500408
# MSE: 11.222156797770078
# RMSE: 3.349948775394943
#          Coeffecient
# punches     1.017701
# saves       0.022130

# %% [markdown]
# Linear Regression of Goals with Appearances,tackles,passes,assists,shots,crosses,hit woodwork.

# %%
 y = df['goals']
X = df[['appearances','tackles','passes','assists','shots','crosses','hit woordwork']]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
print('Coefficients: \n', lm.coef_)
predictions = lm.predict( X_test)
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Coefficients:
#  [-7.09534707e-01 -3.91407979e-02  5.06541234e-04  5.76554542e-01
#   7.03686156e-02 -1.24754700e-02  1.52908405e+00]
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
sns.distplot((y_test-predictions),bins=50);
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
# MAE: 1.9129917858362337
# MSE: 5.841576192093472
# RMSE: 2.41693528918204
#                Coeffecient
# appearances      -0.709535
# tackles          -0.039141
# passes            0.000507
# assists           0.576555
# shots             0.070369
# crosses          -0.012475
# hit woordwork     1.529084

# %% [markdown]
# Linear Regression of Appearances with blocks,clearances and headed clearances.

# %%
 y = df['appearances']
X = df[['blocks','clearances','headed clearances']]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
print('Coefficients: \n', lm.coef_)
predictions = lm.predict( X_test)
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Coefficients:
#  [ 0.01672335  0.04277188 -0.07100416]
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
sns.distplot((y_test-predictions),bins=50);
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
# MAE: 1.7628630143716595
# MSE: 4.669669965991048
# RMSE: 2.160941916385317
#                    Coeffecient
# blocks                0.016723
# clearances            0.042772
# headed clearances    -0.071004

# %% [markdown]
# Linear Regression of Midfielder goals with appearances,tackles,passes,assists,shots,crosses and hit woordwwork.

# %%
f = df.loc[df['position'] == 'Midfielder']
  
y = f['goals']
X = f[['appearances','tackles','passes','assists','shots','crosses','hit woordwork']]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
print('Coefficients: \n', lm.coef_)
predictions = lm.predict( X_test)
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Coefficients:
#  [0. 0. 0. 0. 0. 0. 0.]
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
sns.distplot((y_test-predictions),bins=50);
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
# MAE: 2.0
# MSE: 4.0
# RMSE: 2.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-49c568f0ba57> in <module>()
#       4 print('MSE:', metrics.mean_squared_error(y_test, predictions))
#       5 print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# ----> 6 sns.distplot((y_test-predictions),bins=50);
#       7 coeffecients = pd.DataFrame(lm.coef_,X.columns)
#       8 coeffecients.columns = ['Coeffecient']
#
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
# ...

# %% [markdown]
# Linear Regression of Forward goals with appearances,passes,assists,shots and hit woordwwork.

# %%
f = df.loc[df['position'] == 'Forward']
  
y = f['goals']
X = f[['appearances','passes','assists','shots','hit woordwork']]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
print('Coefficients: \n', lm.coef_)
predictions = lm.predict( X_test)
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
sns.distplot((y_test-predictions),bins=50);
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients

# %% [markdown]
# Linear Regression of Forward goals with appearances,passes,assists,shots and hit woordwwork.

# %%
f = df.loc[df['position'] == 'Forward']
  
y = f['appearances']
X = f[['goals','passes','assists','shots','hit woordwork']]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
print('Coefficients: \n', lm.coef_)
predictions = lm.predict( X_test)
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
sns.distplot((y_test-predictions),bins=50);
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients

# %% [markdown]
# Linear Regression of Forward  appearances and shots.  .

# %%
f = df.loc[df['position'] == 'Forward']
  
y = f['appearances']
X = f[['goals']]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
print('Coefficients: \n', lm.coef_)
predictions = lm.predict( X_test)
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
sns.distplot((y_test-predictions),bins=50);
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients

# %% [markdown]
# Linear Regression of Forward appearances with goals,passes,assists,shots and hit woordwwork.

# %%
f = df.loc[df['position'] == 'Forward']
  
y = f['appearances']
X = f[['goals','passes','assists','shots','hit woordwork']]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
print('Coefficients: \n', lm.coef_)
predictions = lm.predict( X_test)
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
sns.distplot((y_test-predictions),bins=50);
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients

# %% [markdown]
# Linear Regression of Midfielder goals with appearances,passes,assists,shots,crosses and hit woordwwork.

# %%
f = df.loc[df['position'] == 'Midfielder']
  
y = f['appearances']
X = f[['goals','passes','assists','shots','crosses','hit woordwork']]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
print('Coefficients: \n', lm.coef_)
predictions = lm.predict( X_test)
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
sns.distplot((y_test-predictions),bins=50);
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients

# %% [markdown]
# Linear Regression of Defender  appearances with clearances and blocks.

# %%
f = df.loc[df['position'] == 'Defender']
  
y = f['appearances']
X = f[['clearances','blocks']]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
print('Coefficients: \n', lm.coef_)
predictions = lm.predict( X_test)
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Coefficients:
#  [0.02423633 0.23522069]
# Text(0, 0.5, 'Predicted Y')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
sns.distplot((y_test-predictions),bins=50);
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
# MAE: 3.678980155565572
# MSE: 34.783202037277526
# RMSE: 5.897728548965061
#             Coeffecient
# clearances     0.024236
# blocks         0.235221
